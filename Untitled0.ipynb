# %% [markdown]
# import the libraries 📥

# %%
import sqlite3
import json
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
conn = sqlite3.connect("Library Database.db")

members = pd.read_sql("SELECT * FROM members", conn)
books = pd.read_sql("SELECT * FROM books", conn)
checkouts = pd.read_sql("SELECT * FROM checkouts", conn)

# %% [markdown]
# explore the database tables 🕵️

# %%
print(f"members: {members.shape[0]} rows")
print(f"books:  {books.shape[0]} rows")
print(f"checkouts:  {checkouts.shape[0]} rows")
# Out:
# members: 80 rows
# books:  32 rows
# checkouts:  391 rows

# %%
members.head()
# Out:
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1003     Bassel    Hegazy    6.0        Maadi            Active
# 3       1004      Fares     Wahba    7.0        Maadi          inactive
# 4       1005    Youssef     Halim    9.0        Maadi            Active
#
#     join_date
# 0  2023-04-05
# 1         NaN
# 2  2025-04-23
# 3  2024-10-09
# 4  2024-05-05

# %%
books.head()
# Out:
#    book_id                title         author
# 0      501      The Silver Kite  Amina Darwish
# 1      502       Desert Compass  Amina Darwish
# 2      503    The Lantern Maker   Adel Roushdy
# 3      504  Rooftop Astronomers   Adel Roushdy
# 4      505  Letters to the Nile      Aya Hafez

# %%
checkouts.head()
# Out:
#    checkout_id  member_id  book_id checkout_date return_date
# 0         9263       1047      517    2024-10-21  2024-11-07
# 1         9340       1072      513    2025-08-24  2025-09-01
# 2         9231       1053      523    2024-02-04  2024-02-16
# 3         9129       1032      513    2025-06-21  2025-06-29
# 4         9370       1079      511    2025-11-11  2025-12-03

# %%
#create a function to run queries
def run(query):
  return pd.read_sql_query(query,conn)

# %% [markdown]
# answer ✍️ 5 question ❓ using SQL

# %%
#Q1:How much is each member borrowing?
query='''SELECT
      m.first_name || ' ' || m.last_name AS member_name,
       COUNT(c.checkout_id) AS total_checkouts
       FROM members m
       LEFT JOIN checkouts c
       ON m.member_id = c.member_id
      GROUP BY
      m.first_name,
      m.last_name
    '''
print("each student number of books borrowed: ")
run(query)
# Out:
# each student number of books borrowed:
#        member_name  total_checkouts
# 0        Adam Badr                2
# 1       Adam Fahmy               17
# 2      Adam Shafik                5
# 3      Ahmed Fahmy               10
# 4      Ahmed Gamal                1
# ..             ...              ...
# 75  Youssef Hegazy               17
# 76   Youssef Kamel                0
# 77      Ziad Fahmy                8
# 78      Ziad Fouad                2
# 79      Ziad Saleh               19
#
# [80 rows x 2 columns]

# %%
#Q2:Which books match a chosen author pattern?
query='''
SELECT title,author FROM books
WHERE author LIKE '%ou%'
'''
print("books contain 'ou' : ")
run(query)
# Out:
# books contain 'ou' :
#                     title          author
# 0       The Lantern Maker    Adel Roushdy
# 1     Rooftop Astronomers    Adel Roushdy
# 2  Circuits for Beginners    Galal Mounir
# 3   The Robot in Row Nine    Galal Mounir
# 4    Storms and Sailboats   Mahmoud Rafei
# 5   The Clockwork Orchard   Mahmoud Rafei
# 6    Notes from the Delta  Mona Kholoussy
# 7       The Glass Beehive  Mona Kholoussy

# %%
#Q3:What are the most popular books?"FRIST 5"
query='''SELECT b.title ,
COUNT(c.checkout_id) AS total_checkouts
FROM books b
LEFT JOIN checkouts c ON b.book_id = c.book_id
GROUP BY b.title
ORDER BY
total_checkouts DESC
LIMIT 5'''
print("top 5 borrowed books:")
run(query)
# Out:
# top 5 borrowed books:
#                     title  total_checkouts
# 0         The Silver Kite               57
# 1   Fossils and Fireflies               55
# 2  Circuits for Beginners               46
# 3        Kites Over Cairo               38
# 4    Storms and Sailboats               25

# %%
#Q4:4. Who are the most active readers?
query='''SELECT m.first_name || ' ' || m.last_name AS member_name,
         COUNT(c.checkout_id) AS BOROWS
         FROM members m
         LEFT JOIN checkouts c
         ON m.member_id = c.member_id
         GROUP BY
         m.first_name,
         m.last_name
         ORDER BY
         BOROWS DESC
         LIMIT 10'''
print("top 10 readers:")
run(query)
# Out:
# top 10 readers:
#       member_name  BOROWS
# 0       Aya Wahba      25
# 1    Sherif Saleh      21
# 2      Ziad Saleh      19
# 3   Mostafa Fouad      18
# 4      Nour Nabil      18
# 5      Adam Fahmy      17
# 6    Ahmed Shafik      17
# 7  Youssef Hegazy      17
# 8      Reem Osman      16
# 9     Sara Rashad      16

# %%
#Q5:What does a neighborhood's activity look like further back in time?
query='''SELECT
m.first_name || ' ' || m.last_name AS member_name,
         COUNT(c.checkout_id) AS BOROWS
         FROM members m
         JOIN checkouts c
         ON m.member_id = c.member_id
         WHERE m.neighborhood ='Maadi'
         GROUP BY
         m.member_id, m.first_name, m.last_name
         ORDER BY
         c.checkout_date DESC
         limit 10
         OFFSET 10
         '''
print("readers actvity in Maadi neighborhood:")
run(query)
# Out:
# readers actvity in Maadi neighborhood:
#      member_name  BOROWS
# 0      Adam Badr       2
# 1    Menna Halim       2
# 2  Salma Ibrahim       1
# 3  Youssef Fouad       6
# 4    Dina Rashad       7
# 5   Habiba Nabil       1
# 6    Fares Saleh       2
# 7  Youssef Halim       3

# %% [markdown]
# merge the 3 sources file

# %%
#merge checkouts and members dataframes 
stage1 = checkouts.merge(
    members,
    on="member_id",
    how="left")
print(stage1.shape)
stage1.head()
# Out:
# (391, 11)
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0         9263       1047      517    2024-10-21  2024-11-07       Sara
# 1         9340       1072      513    2025-08-24  2025-09-01       Seif
# 2         9231       1053      523    2024-02-04  2024-02-16       Adam
# 3         9129       1032      513    2025-06-21  2025-06-29       Nada
# 4         9370       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27

# %%
#merge stage1(members and checkouts) and books dataframes
stage2 = stage1.merge(
    books,
    on="book_id",
    how="left")
print(stage2.shape)
stage2.head()
# Out:
# (391, 13)
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0         9263       1047      517    2024-10-21  2024-11-07       Sara
# 1         9340       1072      513    2025-08-24  2025-09-01       Seif
# 2         9231       1053      523    2024-02-04  2024-02-16       Adam
# 3         9129       1032      513    2025-06-21  2025-06-29       Nada
# 4         9370       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date  \
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27
#
#                      title        author
# 0  Shadows on the Corniche   Hani Nagati
# 1   Circuits for Beginners  Galal Mounir
# ...

# %%
#read json file 
Book_Catalog = pd.read_json("Book Catalog.json")

# %%
#explore the json data
Book_Catalog.head()
# Out:
#    book_id       genre  pages  publication_year            publisher
# 0      501   Adventure    128            2017.0           Nile Press
# 1      502   Adventure    109            2018.0          Delta House
# 2      503  Historical    259               NaN           Nile Press
# 3      504     Science    319            2009.0  Cairo Young Readers
# 4      505  Historical    216            2024.0          Oasis Books

# %%
#merge stage2(members, checkouts, and books) and Book_Catalog 
#to add each book information
stage3 = stage2.merge(
    Book_Catalog,
    on="book_id",
    how="left")
print(stage3.shape)
stage3.head()
# Out:
# (391, 17)
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0         9263       1047      517    2024-10-21  2024-11-07       Sara
# 1         9340       1072      513    2025-08-24  2025-09-01       Seif
# 2         9231       1053      523    2024-02-04  2024-02-16       Adam
# 3         9129       1032      513    2025-06-21  2025-06-29       Nada
# 4         9370       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date  \
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27
#
#                      title        author       genre  pages  publication_year  \
# ...

# %%
Reading_Kickoff = pd.read_html("Reading Kickoff Signups.html")

reading_kickoff = Reading_Kickoff[0]#to take the table
print(reading_kickoff.shape)
# Out:
# (26, 3)

# %%
#explore the reading_kickoff data 
reading_kickoff.head()
# Out:
#    Member ID  Book ID Checkout Date
# 0       1026      522    2025-07-11
# 1       1049      520    2025-07-11
# 2       1062      525    2025-07-05
# 3       1065      520    2025-07-07
# 4       1104      515    2025-07-07

# %%
#change coulmn names from capital to small to be able to be added
reading_kickoff = reading_kickoff.rename(columns={
    'Member ID': 'member_id',
    'Book ID': 'book_id',
    'Checkout Date': 'checkout_date'
})

# %%
#ensure that the column names are changed
reading_kickoff.head()
# Out:
#    member_id  book_id checkout_date
# 0       1026      522    2025-07-11
# 1       1049      520    2025-07-11
# 2       1062      525    2025-07-05
# 3       1065      520    2025-07-07
# 4       1104      515    2025-07-07

# %%
#adjust the reading_kickoff data to be able to merge with other data
kickoff_stage1 = reading_kickoff.merge(members, on='member_id', how='left')
kickoff_stage2 = kickoff_stage1.merge(books, on='book_id', how='left')
kickoff_stage3 = kickoff_stage2.merge(Book_Catalog, on='book_id', how='left')

# %%
#merge all data in one dataset
final_dataset = pd.concat([stage3, kickoff_stage3], ignore_index=True)
final_dataset.shape
# Out:
# (417, 17)

# %%
#ensure that the webpage data is added correctly
final_dataset.tail(26)
# Out:
#      checkout_id  member_id  book_id checkout_date return_date first_name  \
# 391          NaN       1026      522    2025-07-11         NaN       Nada
# 392          NaN       1049      520    2025-07-11         NaN      Ahmed
# 393          NaN       1062      525    2025-07-05         NaN      Tarek
# 394          NaN       1065      520    2025-07-07         NaN       Adam
# 395          NaN       1104      515    2025-07-07         NaN        NaN
# 396          NaN       1009      503    2025-07-09         NaN     Hassan
# 397          NaN       1063      522    2025-07-07         NaN      Layla
# 398          NaN       1022      511    2025-07-12         NaN    Youssef
# 399          NaN       1029      523    2025-07-09         NaN       Rana
# 400          NaN       1201      509    2025-07-10         NaN        NaN
# 401          NaN       1005      513    2025-07-10         NaN    Youssef
# 402          NaN       1104      526    2025-07-05         NaN        NaN
# ...

# %%
final_dataset.to_csv('task1_combined_data.csv', index=False)

# %% [markdown]
#                              steps done
# At first I merged  the members and checkout table together based on member id
# which is primary key in members table and forgin key in checkouts table giving
# us a table contain each member information and checkouts information then I merged
# this table with books table based on book id so I have all information about members
# and checkouts then I merged the json file that contain books information with the
# table based on book id so I have all members info, checkouts and each book information
# after that I extracted the Reading Kickoff checkout data from the webpage, prepared it
# to have the same structure as the existing checkout data, and then
# added it to the combined dataset so I would not lose any data

# %% [markdown]
#                  API vs Web Scraping
# Webpages are designed to be seen by user not to deliver data automatically ,
# SO it's is extracted manually. While APIs are designed to deliver data
# directly in a structured format (like JSON).In this project, it mattered
# because the webpage didn't have an API, so we did extra cleaning steps to
# make the web data match our database before combining them.

# %%
#read the csv file
df= pd.read_csv('task1_combined_data.csv')
print("data loaded successfully 👍")
# Out:
# data loaded successfully 👍

# %% [markdown]
# Explore the file to ensure it's the right one 🕵️

# %%
df.head()
# Out:
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0       9263.0       1047      517    2024-10-21  2024-11-07       Sara
# 1       9340.0       1072      513    2025-08-24  2025-09-01       Seif
# 2       9231.0       1053      523    2024-02-04  2024-02-16       Adam
# 3       9129.0       1032      513    2025-06-21  2025-06-29       Nada
# 4       9370.0       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date  \
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27
#
#                      title        author       genre  pages  publication_year  \
# ...

# %%
df.shape
# Out:
# (417, 17)

# %% [markdown]
# start cleaning process 🧹

# %%
df_raw = df.copy()

# %% [markdown]
# I didn't use any coulmn to select the diuplicates but only the rows which are completly the
#  same because each member nay have more than a checkout so removing any of them will be wronge
#  ❌

# %%
print(df.duplicated().sum())
# Out:
# 8

# %%
df = df.drop_duplicates(keep='first')
print("Duplicates removed successfully 👍")
# Out:
# Duplicates removed successfully 👍

# %% [markdown]
# fill ✍️ the missing values ❓

# %%
print(df.isna().sum())
# Out:
# checkout_id          26
# member_id             0
# book_id               0
# checkout_date         0
# return_date          91
# first_name            5
# last_name             5
# grade                41
# neighborhood          5
# membership_status     5
# join_date            11
# title                 0
# author                0
# genre                 0
# pages                 0
# publication_year     33
# publisher             0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ❌
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ❌
#
# first_name            ❌
#
# last_name             ❌
#
# grade                 ❌
#
# neighborhood          ❌
#
# membership_status     ❌
#
# join_date             ❌
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ❌
#
# publisher             ✅

# %% [markdown]
# there are 26 missing checkout id
# so i will take the highest id and add
# one till i fill all the missing values
# because removing all of them is wronge❌

# %%
missing_ids = df['checkout_id'].isna()

start_id = int(df['checkout_id'].max()) + 1

df.loc[missing_ids, 'checkout_id'] = range(
    start_id,
    start_id + missing_ids.sum()
)

# %%
# acheck that there is no missing values
df.isna().sum()
# Out:
# checkout_id           0
# member_id             0
# book_id               0
# checkout_date         0
# return_date          91
# first_name            5
# last_name             5
# grade                41
# neighborhood          5
# membership_status     5
# join_date            11
# title                 0
# author                0
# genre                 0
# pages                 0
# publication_year     33
# publisher             0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ✅
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ❌
#
# first_name            ❌
#
# last_name             ❌
#
# grade                 ❌
#
# neighborhood          ❌
#
# membership_status     ❌
#
# join_date             ❌
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ❌
#
# publisher             ✅

# %% [markdown]
# i will remove the rows contain missing values in the frist name
# because we can't pridict the names

# %%
df.dropna(subset=['first_name'], inplace=True)

# %%
df.isna().sum()
# Out:
# checkout_id           0
# member_id             0
# book_id               0
# checkout_date         0
# return_date          86
# first_name            0
# last_name             0
# grade                36
# neighborhood          0
# membership_status     0
# join_date             6
# title                 0
# author                0
# genre                 0
# pages                 0
# publication_year     33
# publisher             0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ✅
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ❌
#
# first_name            ✅
#
# last_name             ✅
#
# grade                 ❌
#
# neighborhood          ✅
#
# membership_status     ✅
#
# join_date             ❌
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ❌
#
# publisher             ✅

# %% [markdown]
# after removing the rows wjich has no frist name
# missing values in last_name neighborhood
# membership_status dissapeared

# %%
#fill grade mising values with median
mid1=df["grade"].median()
df["grade"]=df["grade"].fillna(mid1)

# %%
print(df.isna().sum())
# Out:
# checkout_id           0
# member_id             0
# book_id               0
# checkout_date         0
# return_date          86
# first_name            0
# last_name             0
# grade                 0
# neighborhood          0
# membership_status     0
# join_date             6
# title                 0
# author                0
# genre                 0
# pages                 0
# publication_year     33
# publisher             0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ✅
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ❌
#
# first_name            ✅
#
# last_name             ✅
#
# grade                 ✅
#
# neighborhood          ✅
#
# membership_status     ✅
#
# join_date             ❌
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ❌
#
# publisher             ✅

# %%
print("mode")
print(df['publication_year'].mode())
print("median")
print(df['publication_year'].median())
print("mean")
print(df['publication_year'].mean())
# Out:
# mode
# 0    2024.0
# Name: publication_year, dtype: float64
# median
# 2017.0
# mean
# 2017.4393530997304

# %%
#fill publication_year mising values with median
mid2=df["publication_year"].median()
df["publication_year"]=df["publication_year"].fillna(mid2)

# %%
print(df.isna().sum())
# Out:
# checkout_id           0
# member_id             0
# book_id               0
# checkout_date         0
# return_date          86
# first_name            0
# last_name             0
# grade                 0
# neighborhood          0
# membership_status     0
# join_date             6
# title                 0
# author                0
# genre                 0
# pages                 0
# publication_year      0
# publisher             0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ✅
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ❌
#
# first_name            ✅
#
# last_name             ✅
#
# grade                 ✅
#
# neighborhood          ✅
#
# membership_status     ✅
#
# join_date             ❌
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ✅
#
# publisher             ✅

# %%
# Convert dates to datetime
df['return_date'] = pd.to_datetime(df['return_date'], errors='coerce')
df["return_date"]=df["return_date"].fillna("still active")
#i will Keep missing return dates as still active because they  represent books that have not been returned yet
#instead of deleting 86 rows

# %%
print(df.isna().sum())
# Out:
# checkout_id          0
# member_id            0
# book_id              0
# checkout_date        0
# return_date          0
# first_name           0
# last_name            0
# grade                0
# neighborhood         0
# membership_status    0
# join_date            6
# title                0
# author               0
# genre                0
# pages                0
# publication_year     0
# publisher            0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ✅
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ✅
#
# first_name            ✅
#
# last_name             ✅
#
# grade                 ✅
#
# neighborhood          ✅
#
# membership_status     ✅
#
# join_date             ❌
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ✅
#
# publisher             ✅

# %%
# Drop rows with missing 'join_date' values because we can't guess it
df = df.dropna(subset=['join_date'])

# %%
print(df.isna().sum())
# Out:
# checkout_id          0
# member_id            0
# book_id              0
# checkout_date        0
# return_date          0
# first_name           0
# last_name            0
# grade                0
# neighborhood         0
# membership_status    0
# join_date            0
# title                0
# author               0
# genre                0
# pages                0
# publication_year     0
# publisher            0
# dtype: int64

# %% [markdown]
# report of missing values
# ❌=missing values
# ✅= comleted
# checkout_id           ✅
#
# member_id             ✅
#
# book_id               ✅
#
# checkout_date         ✅
#
# return_date           ✅
#
# first_name            ✅
#
# last_name             ✅
#
# grade                 ✅
#
# neighborhood          ✅
#
# membership_status     ✅
#
# join_date             ✅
#
# title                 ✅
#
# author                ✅
#
# genre                 ✅
#
# pages                 ✅
#
# publication_year      ✅
#
# publisher             ✅

# %% [markdown]
# fix inconssitent values

# %%
df['neighborhood'].value_counts()
# Out:
# neighborhood
# Nasr City     97
# Maadi         92
# Heliopolis    86
# Zamalek       58
# Shubra        34
# Maadi         19
# zamalek       10
# NASR CITY      1
# HELIOPOLIS     1
# Name: count, dtype: int64

# %%
df['neighborhood'] = df['neighborhood'].str.strip().str.title()
df["neighborhood"].value_counts()
# Out:
# neighborhood
# Maadi         111
# Nasr City      98
# Heliopolis     87
# Zamalek        68
# Shubra         34
# Name: count, dtype: int64

# %%
df['membership_status'].value_counts()
# Out:
# membership_status
# Active      272
# Inactive     52
# active       43
# inactive     31
# Name: count, dtype: int64

# %%
df['membership_status'] = df['membership_status'].str.strip().str.title()
df["membership_status"].value_counts()
# Out:
# membership_status
# Active      315
# Inactive     83
# Name: count, dtype: int64

# %%
df['title'] = df['title'].str.strip().str.title()
df["title"].value_counts()
# Out:
# title
# The Silver Kite            54
# Fossils And Fireflies      53
# Circuits For Beginners     47
# Kites Over Cairo           37
# Storms And Sailboats       26
# The Paper Boat Club        14
# The Beekeeper'S Almanac    11
# The Copper Telescope       10
# Marbles And Mirrors        10
# Riddles Of The Red Sea     10
# The Puzzle Merchant        10
# Winter In Alexandria        9
# The Ninth Lighthouse        9
# The Missing Metronome       9
# The Lantern Maker           9
# Letters To The Nile         8
# The Last Bookmark           8
# The Glass Beehive           7
# Desert Compass              7
# A Garden Of Equations       6
# The Sandstone Key           6
# The Robot In Row Nine       6
# Songs Of The Oasis          5
# The Cartographer'S Cat      5
# Shadows On The Corniche     4
# The Clockwork Orchard       4
# Notes From The Delta        4
# The Weaver'S Daughter       3
# Footsteps In The Dust       2
# Voices In The Library       2
# Rooftop Astronomers         2
# ...

# %%
df['author'] = df['author'].str.strip().str.title()
df["author"].value_counts()
# Out:
# author
# Amina Darwish     61
# Dalia Serry       54
# Galal Mounir      53
# Jasmine Wahdan    47
# Mahmoud Rafei     30
# Aya Hafez         22
# Diaa Sultan       19
# Hoda Bakry        16
# Karim Elwy        16
# Sara Tantawy      16
# Farida Anwar      14
# Hani Nagati       13
# Mona Kholoussy    11
# Adel Roushdy      11
# Samir Zohdy       10
# Laila Shokry       5
# Name: count, dtype: int64

# %%
df['publisher'] = df['publisher'].str.strip().str.title()
df["publisher"].value_counts()
# Out:
# publisher
# Nile Press             197
# Oasis Books            110
# Cairo Young Readers     51
# Delta House             40
# Name: count, dtype: int64

# %%
# check if there is outlier 
Q1 = df['grade'].quantile(0.25)
Q3 = df['grade'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"IQR: {IQR:.1f}")
print(f"Lower bound: {lower_bound:.1f}")
print(f"Upper bound: {upper_bound:.1f}")
print(f"Outliers above upper bound: {(df['grade'] > upper_bound).sum()}")
# Out:
# Q1: 7.0
# Q3: 9.0
# IQR: 2.0
# Lower bound: 4.0
# Upper bound: 12.0
# Outliers above upper bound: 0
