# %%
import sqlite3
import json
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
conn = sqlite3.connect("/content/db")

members = pd.read_sql("SELECT * FROM members", conn)
books = pd.read_sql("SELECT * FROM books", conn)
checkouts = pd.read_sql("SELECT * FROM checkouts", conn)

print(f"members: {members.shape[0]} rows")
print(f"books:  {books.shape[0]} rows")
print(f"checkouts:  {checkouts.shape[0]} rows")
members.head()
# Out:
# members: 80 rows
# books:  32 rows
# checkouts:  391 rows
#    member_id first_name last_name  grade neighborhood membership_status  \
# 0       1001      Salma   Ibrahim    8.0        Maadi            Active
# 1       1002      Fares     Saleh    9.0        Maadi            Active
# 2       1003     Bassel    Hegazy    6.0        Maadi            Active
# 3       1004      Fares     Wahba    7.0        Maadi          inactive
# 4       1005    Youssef     Halim    9.0        Maadi            Active
#
#     join_date
# 0  2023-04-05
# 1        None
# 2  2025-04-23
# 3  2024-10-09
# 4  2024-05-05

# %%
books.head()
# Out:
#    book_id                title         author
# 0      501      The Silver Kite  Amina Darwish
# 1      502       Desert Compass  Amina Darwish
# 2      503    The Lantern Maker   Adel Roushdy
# 3      504  Rooftop Astronomers   Adel Roushdy
# 4      505  Letters to the Nile      Aya Hafez

# %%
checkouts.head()
# Out:
#    checkout_id  member_id  book_id checkout_date return_date
# 0         9263       1047      517    2024-10-21  2024-11-07
# 1         9340       1072      513    2025-08-24  2025-09-01
# 2         9231       1053      523    2024-02-04  2024-02-16
# 3         9129       1032      513    2025-06-21  2025-06-29
# 4         9370       1079      511    2025-11-11  2025-12-03

# %%
def run(query):
  return pd.read_sql_query(query,conn)

# %%
#Q1:How much is each member borrowing?
query='''SELECT m.first_name,m.last_name,
       COUNT(c.checkout_id) AS total_checkouts
       FROM members m
       LEFT JOIN checkouts c
       ON m.member_id = c.member_id
      GROUP BY
      m.first_name,
      m.last_name
    '''
print("each student number of books borrowed: ")
run(query)
# Out:
# each student number of books borrowed:
#    first_name last_name  total_checkouts
# 0        Adam      Badr                2
# 1        Adam     Fahmy               17
# 2        Adam    Shafik                5
# 3       Ahmed     Fahmy               10
# 4       Ahmed     Gamal                1
# ..        ...       ...              ...
# 75    Youssef    Hegazy               17
# 76    Youssef     Kamel                0
# 77       Ziad     Fahmy                8
# 78       Ziad     Fouad                2
# 79       Ziad     Saleh               19
#
# [80 rows x 3 columns]

# %%
#Q2:Which books match a chosen author pattern?
query='''
SELECT title FROM books
WHERE title LIKE '%on%'
'''
print("books contain 'on' : ")
run(query)
# Out:
# books contain 'on' :
#                      title
# 0      Rooftop Astronomers
# 1    The Missing Metronome
# 2       Songs of the Oasis
# 3  Shadows on the Corniche
# 4    A Garden of Equations
# 5        The Sandstone Key

# %%
#Q3:What are the most popular books?"FRIST 5"
query='''SELECT b.title ,
COUNT(c.checkout_id) AS total_checkouts
FROM books b
LEFT JOIN checkouts c ON b.book_id = c.book_id
GROUP BY b.title
ORDER BY
total_checkouts DESC
LIMIT 5'''
print("top 5 borrowed books:")
run(query)
# Out:
# top 5 borrowed books:
#                     title  total_checkouts
# 0         The Silver Kite               57
# 1   Fossils and Fireflies               55
# 2  Circuits for Beginners               46
# 3        Kites Over Cairo               38
# 4    Storms and Sailboats               25

# %%
#Q4:4. Who are the most active readers?
query='''SELECT m.first_name,m.last_name,
         COUNT(c.checkout_id) AS BOROWS
         FROM members m
         LEFT JOIN checkouts c
         ON m.member_id = c.member_id
         GROUP BY
         m.first_name,
         m.last_name
         ORDER BY
         BOROWS DESC
         LIMIT 10'''
print("top 10 readers:")
run(query)
# Out:
# top 10 readers:
#   first_name last_name  BOROWS
# 0        Aya     Wahba      25
# 1     Sherif     Saleh      21
# 2       Ziad     Saleh      19
# 3    Mostafa     Fouad      18
# 4       Nour     Nabil      18
# 5       Adam     Fahmy      17
# 6      Ahmed    Shafik      17
# 7    Youssef    Hegazy      17
# 8       Reem     Osman      16
# 9       Sara    Rashad      16

# %%
#Q5:What does a neighborhood's activity look like further back in time?
query='''SELECT m.first_name,m.last_name,
         COUNT(c.checkout_id) AS BOROWS
         FROM members m
         JOIN checkouts c
         ON m.member_id = c.member_id
         WHERE m.neighborhood ='Maadi'
         GROUP BY
         m.member_id, m.first_name, m.last_name
         ORDER BY
         c.checkout_date DESC
         limit 10
         OFFSET 10
         '''
print("readers actvity in Maadi neighborhood:")
run(query)
# Out:
# readers actvity in Maadi neighborhood:
#   first_name last_name  BOROWS
# 0       Adam      Badr       2
# 1      Menna     Halim       2
# 2      Salma   Ibrahim       1
# 3    Youssef     Fouad       6
# 4       Dina    Rashad       7
# 5     Habiba     Nabil       1
# 6      Fares     Saleh       2
# 7    Youssef     Halim       3

# %%
books.head()
# Out:
#    book_id                title         author
# 0      501      The Silver Kite  Amina Darwish
# 1      502       Desert Compass  Amina Darwish
# 2      503    The Lantern Maker   Adel Roushdy
# 3      504  Rooftop Astronomers   Adel Roushdy
# 4      505  Letters to the Nile      Aya Hafez

# %%
query='''SELECT *
FROM checkouts c
LEFT JOIN books b
ON b.book_id = c.book_id;
'''
run(query)
# Out:
#      checkout_id  member_id  book_id checkout_date return_date  book_id  \
# 0           9263       1047      517    2024-10-21  2024-11-07      517
# 1           9340       1072      513    2025-08-24  2025-09-01      513
# 2           9231       1053      523    2024-02-04  2024-02-16      523
# 3           9129       1032      513    2025-06-21  2025-06-29      513
# 4           9370       1079      511    2025-11-11  2025-12-03      511
# ..           ...        ...      ...           ...         ...      ...
# 386         9232       1044      513    2025-05-26  2025-06-11      513
# 387         9084       1008      511    2024-06-27  2024-07-22      511
# 388         9116       1024      519    2025-01-10  2025-02-09      519
# 389         9352       1076      501    2025-02-02        None      501
# 390         9246       1044      529    2025-06-25  2025-07-04      529
#
#                        title          author
# 0    Shadows on the Corniche     Hani Nagati
# 1     Circuits for Beginners    Galal Mounir
# 2      Footsteps in the Dust    Laila Shokry
# 3     Circuits for Beginners    Galal Mounir
# 4       Winter in Alexandria    Farida Anwar
# ..                       ...             ...
# 386   Circuits for Beginners    Galal Mounir
# 387     Winter in Alexandria    Farida Anwar
# 388         Kites Over Cairo  Jasmine Wahdan
# 389          The Silver Kite   Amina Darwish
# 390   Riddles of the Red Sea    Sara Tantawy
#
# [391 rows x 8 columns]

# %%
stage1 = checkouts.merge(
    members,
    on="member_id",
    how="left")
print(stage1.shape)
stage1.head()
# Out:
# (391, 11)
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0         9263       1047      517    2024-10-21  2024-11-07       Sara
# 1         9340       1072      513    2025-08-24  2025-09-01       Seif
# 2         9231       1053      523    2024-02-04  2024-02-16       Adam
# 3         9129       1032      513    2025-06-21  2025-06-29       Nada
# 4         9370       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27

# %%
stage2 = stage1.merge(
    books,
    on="book_id",
    how="left")
print(stage2.shape)
stage2.head()
# Out:
# (391, 13)
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0         9263       1047      517    2024-10-21  2024-11-07       Sara
# 1         9340       1072      513    2025-08-24  2025-09-01       Seif
# 2         9231       1053      523    2024-02-04  2024-02-16       Adam
# 3         9129       1032      513    2025-06-21  2025-06-29       Nada
# 4         9370       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date  \
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27
#
#                      title        author
# 0  Shadows on the Corniche   Hani Nagati
# 1   Circuits for Beginners  Galal Mounir
# 2    Footsteps in the Dust  Laila Shokry
# 3   Circuits for Beginners  Galal Mounir
# 4     Winter in Alexandria  Farida Anwar

# %%
json_data = pd.read_json("/content/json")

# %%
json_data.head()
# Out:
#    book_id       genre  pages  publication_year            publisher
# 0      501   Adventure    128            2017.0           Nile Press
# 1      502   Adventure    109            2018.0          Delta House
# 2      503  Historical    259               NaN           Nile Press
# 3      504     Science    319            2009.0  Cairo Young Readers
# 4      505  Historical    216            2024.0          Oasis Books

# %%
stage3 = stage2.merge(
    json_data,
    on="book_id",
    how="left")
print(stage3.shape)
stage3.head()
# Out:
# (391, 17)
#    checkout_id  member_id  book_id checkout_date return_date first_name  \
# 0         9263       1047      517    2024-10-21  2024-11-07       Sara
# 1         9340       1072      513    2025-08-24  2025-09-01       Seif
# 2         9231       1053      523    2024-02-04  2024-02-16       Adam
# 3         9129       1032      513    2025-06-21  2025-06-29       Nada
# 4         9370       1079      511    2025-11-11  2025-12-03       Rana
#
#   last_name  grade neighborhood membership_status   join_date  \
# 0    Rashad    NaN   Heliopolis          Inactive  2024-06-25
# 1      Zaki    9.0      Zamalek            Active  2025-10-21
# 2    Shafik    9.0   Heliopolis            Active  2024-01-03
# 3      Zaki    7.0    Nasr City            Active  2025-10-19
# 4     Osman    8.0       Shubra            Active  2024-10-27
#
#                      title        author       genre  pages  publication_year  \
# 0  Shadows on the Corniche   Hani Nagati     Mystery    338            2015.0
# 1   Circuits for Beginners  Galal Mounir     Science    294            2021.0
# 2    Footsteps in the Dust  Laila Shokry  Historical    276            2018.0
# 3   Circuits for Beginners  Galal Mounir     Science    294            2021.0
# 4     Winter in Alexandria  Farida Anwar  Historical    117            2016.0
#
#      publisher
# 0  Delta House
# 1  Oasis Books
# 2  Oasis Books
# 3  Oasis Books
# 4   Nile Press

# %%
html_tables = pd.read_html("/content/html")

reading_kickoff = html_tables[0]#to take the table
print(reading_kickoff.shape)
reading_kickoff.head()
# Out:
# (26, 3)
#    Member ID  Book ID Checkout Date
# 0       1026      522    2025-07-11
# 1       1049      520    2025-07-11
# 2       1062      525    2025-07-05
# 3       1065      520    2025-07-07
# 4       1104      515    2025-07-07

# %%
#change coulmn names from capital to small to be able to be added
reading_kickoff = reading_kickoff.rename(columns={
    'Member ID': 'member_id',
    'Book ID': 'book_id',
    'Checkout Date': 'checkout_date'
})

reading_kickoff.head()
# Out:
# (26, 3)
#    member_id  book_id checkout_date
# 0       1026      522    2025-07-11
# 1       1049      520    2025-07-11
# 2       1062      525    2025-07-05
# 3       1065      520    2025-07-07
# 4       1104      515    2025-07-07

# %%
kickoff_stage1 = reading_kickoff.merge(members, on='member_id', how='left')
kickoff_stage1.shape
# Out:
# (26, 9)

# %%
kickoff_stage2 = kickoff_stage1.merge(books, on='book_id', how='left')
kickoff_stage3 = kickoff_stage2.merge(json_data, on='book_id', how='left')

# %%
final_dataset = pd.concat([stage3, kickoff_stage3], ignore_index=True)
final_dataset.shape
# Out:
# (417, 17)

# %%
final_dataset.tail(26)
# Out:
#      checkout_id  member_id  book_id checkout_date return_date first_name  \
# 391          NaN       1026      522    2025-07-11         NaN       Nada
# 392          NaN       1049      520    2025-07-11         NaN      Ahmed
# 393          NaN       1062      525    2025-07-05         NaN      Tarek
# 394          NaN       1065      520    2025-07-07         NaN       Adam
# 395          NaN       1104      515    2025-07-07         NaN        NaN
# 396          NaN       1009      503    2025-07-09         NaN     Hassan
# 397          NaN       1063      522    2025-07-07         NaN      Layla
# 398          NaN       1022      511    2025-07-12         NaN    Youssef
# 399          NaN       1029      523    2025-07-09         NaN       Rana
# 400          NaN       1201      509    2025-07-10         NaN        NaN
# 401          NaN       1005      513    2025-07-10         NaN    Youssef
# 402          NaN       1104      526    2025-07-05         NaN        NaN
# 403          NaN       1058      518    2025-07-08         NaN       Lina
# 404          NaN       1002      521    2025-07-08         NaN      Fares
# 405          NaN       1150      530    2025-07-10         NaN        NaN
# 406          NaN       1041      504    2025-07-05         NaN       Nada
# 407          NaN       1055      526    2025-07-11         NaN    Mostafa
# 408          NaN       1061      513    2025-07-06         NaN       Ziad
# 409          NaN       1012      509    2025-07-11         NaN        Ali
# 410          NaN       1007      510    2025-07-07         NaN     Sherif
# 411          NaN       1073      530    2025-07-07         NaN     Yassin
# 412          NaN       1003      501    2025-07-08         NaN     Bassel
# 413          NaN       1017      507    2025-07-11         NaN       Adam
# 414          NaN       1061      504    2025-07-06         NaN       Ziad
# 415          NaN       1201      523    2025-07-08         NaN        NaN
# 416          NaN       1041      512    2025-07-06         NaN       Nada
#
#     last_name  grade neighborhood membership_status   join_date  \
# 391     Saleh    7.0    Nasr City          inactive  2023-11-16
# 392     Gamal    6.0   Heliopolis            Active  2023-06-10
# 393      Adel    7.0      Zamalek            Active  2023-01-22
# 394     Fahmy    6.0      Zamalek            Active  2025-07-12
# 395       NaN    NaN          NaN               NaN         NaN
# 396     Saleh    6.0        Maadi            Active  2025-04-25
# 397     Fouad    6.0      Zamalek            Active  2024-06-21
# 398     Fouad    7.0        Maadi            Active  2025-02-28
# 399     Kamel    6.0    Nasr City            Active  2023-04-03
# 400       NaN    NaN          NaN               NaN         NaN
# 401     Halim    9.0        Maadi            Active  2024-05-05
# 402       NaN    NaN          NaN               NaN         NaN
# 403   Mansour    8.0   Heliopolis            active  2025-07-20
# 404     Saleh    9.0        Maadi            Active        None
# 405       NaN    NaN          NaN               NaN         NaN
# 406    Rashad    7.0    Nasr City            Active  2024-04-02
# 407     Kamel    9.0   Heliopolis            Active  2025-01-04
# 408     Fahmy    9.0      zamalek          Inactive  2023-04-27
# 409    Hegazy    7.0       Maadi             Active  2025-12-08
# 410     Fouad    6.0        Maadi            Active  2025-08-18
# 411     Kamel    7.0      Zamalek          Inactive  2025-08-26
# 412    Hegazy    6.0        Maadi            Active  2025-04-23
# 413      Badr    9.0        Maadi            Active  2025-07-12
# 414     Fahmy    9.0      zamalek          Inactive  2023-04-27
# 415       NaN    NaN          NaN               NaN         NaN
# 416    Rashad    7.0    Nasr City            Active  2024-04-02
#
#                       title          author            genre  pages  \
# 391     The Puzzle Merchant      Karim Elwy          Mystery    104
# 392    The Copper Telescope  Jasmine Wahdan  Science Fiction    136
# 393    Storms and Sailboats   Mahmoud Rafei        Adventure    297
# 394    The Copper Telescope  Jasmine Wahdan  Science Fiction    136
# 395      Songs of the Oasis      Hoda Bakry           Poetry    316
# 396       The Lantern Maker    Adel Roushdy       Historical    259
# 397     The Puzzle Merchant      Karim Elwy          Mystery    104
# 398    Winter in Alexandria    Farida Anwar       Historical    117
# 399   Footsteps in the Dust    Laila Shokry       Historical    276
# 400     Marbles and Mirrors     Diaa Sultan          Mystery    221
# 401  Circuits for Beginners    Galal Mounir          Science    294
# 402   The Clockwork Orchard   Mahmoud Rafei  Science Fiction    125
# 403    The Ninth Lighthouse     Hani Nagati        Adventure    163
# 404   A Garden of Equations      Karim Elwy          Science    211
# 405       The Sandstone Key    Sara Tantawy        Adventure    208
# 406     Rooftop Astronomers    Adel Roushdy          Science    319
# 407   The Clockwork Orchard   Mahmoud Rafei  Science Fiction    125
# 408  Circuits for Beginners    Galal Mounir          Science    294
# 409     Marbles and Mirrors     Diaa Sultan          Mystery    221
# 410   The Missing Metronome     Diaa Sultan          Mystery    134
# 411       The Sandstone Key    Sara Tantawy        Adventure    208
# 412         The Silver Kite   Amina Darwish        Adventure    128
# 413   Fossils and Fireflies     Dalia Serry          Science    160
# 414     Rooftop Astronomers    Adel Roushdy          Science    319
# 415   Footsteps in the Dust    Laila Shokry       Historical    276
# 416  The Cartographer's Cat    Farida Anwar        Adventure    238
#
#      publication_year            publisher
# 391            2016.0  Cairo Young Readers
# 392            2009.0          Oasis Books
# 393            2015.0          Oasis Books
# 394            2009.0          Oasis Books
# 395            2022.0  Cairo Young Readers
# 396               NaN           Nile Press
# 397            2016.0  Cairo Young Readers
# 398            2016.0           Nile Press
# 399            2018.0          Oasis Books
# 400            2011.0           Nile Press
# 401            2021.0          Oasis Books
# 402            2016.0          Delta House
# 403            2011.0          Delta House
# 404            2024.0  Cairo Young Readers
# 405            2012.0          Oasis Books
# 406            2009.0  Cairo Young Readers
# 407            2016.0          Delta House
# 408            2021.0          Oasis Books
# 409            2011.0           Nile Press
# 410            2013.0  Cairo Young Readers
# 411            2012.0          Oasis Books
# 412            2017.0           Nile Press
# 413            2024.0           Nile Press
# 414            2009.0  Cairo Young Readers
# 415            2018.0          Oasis Books
# 416            2022.0          Delta House

# %%
final_dataset.to_csv('task1_combined_data.csv', index=False)
